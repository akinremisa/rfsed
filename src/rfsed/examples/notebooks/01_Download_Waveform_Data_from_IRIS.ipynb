# %% [markdown]
# # Download Waveform Data from IRIS
#
# This notebook demonstrates the process of downloading earthquake data for the purpose of receiver function analysis using [rf](https://github.com/trichter/rf) package

# %% [markdown]
# We first import all the necessary functions and define the Station and Data Center Parameters

# %%
#%% Download data from IRIS 
import os 
import scipy
import matplotlib.pyplot as plt
import numpy as np
from obspy import read_inventory, read_events, UTCDateTime as UTC
from obspy.clients.fdsn import Client
from rfsed.rf import read_rf, RFStream
from rfsed.rf  import get_profile_boxes, iter_event_data, IterMultipleComponents
from rfsed.rf.imaging import plot_profile_map
from rfsed.rf.profile import profile
from tqdm import tqdm
from os.path import exists
from os import mkdir
from rfsed.util import save_Eq_data, save_IRIS_waveform
#------------------------------------------#
savedir=save_IRIS_waveform()
invfile = savedir + '00_eq_stations.xml'
catfile = savedir + '00_eq_events.xml'
datafile = savedir + '00_eq_data.h5'
# stname = input("Input Station Name:")
# staname= str(stname)
# Network = str(input("Input Network Name:"))
# StartDate = str(input("Input Start Date (YYYY-MM-DD):"))
# EndDate = str(input("Input End Date (YYYY-MM-DD):"))
# StationClient=str(input("Input Station Client e.g. IRIS, ORFEUS, GFZ:"))
# EventClient=str(input("Input Event Client e.g. IRIS, ORFEUS, GFZ:"))
# DataClient=str(input("Input Data Client e.g. IRIS, ORFEUS, GFZ:"))
#------------------------------------------#
# Input Examples
staname = 'HGN'
Network = 'NL'
StartDate = '2015-01-01'
EndDate = '2015-08-01'
StationClient='ORFEUS'
EventClient='GFZ'
DataClient='ORFEUS'

# %% [markdown]
# We then download the Station Inventory

# %%
#------------------------------------------#
# Download station inventory
minlat=50.3; maxlat=53.8  #South-North
minlong=3.0; maxlong=7.7 #West-East
if not os.path.exists(invfile):
    client = Client(StationClient)
    inventory = client.get_stations(network=Network, channel='BH?', level='channel', station=staname,
                                    minlatitude = minlat, maxlatitude = maxlat, 
                                    minlongitude = minlong, maxlongitude = maxlong)
    inventory.write(invfile, 'STATIONXML')
inventory = read_inventory(invfile)
# inventory.plot(label=False)
# fig = inventory.plot('local')
#------------------------------------------#

# %% [markdown]
# The catalog of earthquake events within the period of interest and of defined source charateristics is download

# %%
# Download event catalog
stacomp= Network + '.' + staname + '..BHZ'
coords = inventory.get_coordinates(stacomp)
lonlat = (coords['longitude'], coords['latitude'])
long=lonlat[0]
lat=lonlat[1]
if not os.path.exists(catfile):
    client = Client(EventClient)
    kwargs = {'starttime': UTC(StartDate), 'endtime': UTC(EndDate),
              'latitude': lonlat[1], 'longitude': lonlat[0],
              'minradius': 30, 'maxradius': 95,
              'minmagnitude': 5.5, 'maxmagnitude': 10}
    catalog = client.get_events(**kwargs)

    catalog.write(catfile, 'QUAKEML')
catalog = read_events(catfile)
# fig = catalog.plot(label=None)

# %% [markdown]
# The waveform data of the events in the catalog are then downloaded from the appropriate Data Center

# %%
#------------------------------------------#
# Get the data 
if not os.path.exists(datafile):
    client = Client(DataClient)
    stream = RFStream()
    with tqdm() as pbar:
        for s in iter_event_data(catalog, inventory, client.get_waveforms, pbar=pbar):
            stream.extend(s)
    stream.write(datafile, 'H5')  
#%%
eqdata = read_rf(datafile)
for i in eqdata: 
    print(i)
print("Number of Events:", len(eqdata), 'events')
# %%
# Out:
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-01-08T18:54:03.517153Z | 40.0 Hz, 8001 samples | mag:5.5 dist:79.3 baz:28.9 slow:5.42
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-01-08T18:54:03.517153Z | 40.0 Hz, 8001 samples | mag:5.5 dist:79.3 baz:28.9 slow:5.42
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-01-08T18:54:03.517153Z | 40.0 Hz, 8001 samples | mag:5.5 dist:79.3 baz:28.9 slow:5.42
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-13T20:19:17.915225Z | 40.0 Hz, 8001 samples | mag:6.1 dist:87.5 baz:56.4 slow:4.81
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-13T20:19:17.915225Z | 40.0 Hz, 8001 samples | mag:6.1 dist:87.5 baz:56.4 slow:4.81
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-13T20:19:17.915225Z | 40.0 Hz, 8001 samples | mag:6.1 dist:87.5 baz:56.4 slow:4.81
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-16T23:18:46.448505Z | 40.0 Hz, 8001 samples | mag:6.7 dist:82.2 baz:31.9 slow:5.23
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-16T23:18:46.448505Z | 40.0 Hz, 8001 samples | mag:6.7 dist:82.2 baz:31.9 slow:5.23
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-16T23:18:46.448505Z | 40.0 Hz, 8001 samples | mag:6.7 dist:82.2 baz:31.9 slow:5.23
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-20T04:37:45.187295Z | 40.0 Hz, 8001 samples | mag:6.3 dist:82.3 baz:31.5 slow:5.22
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-20T04:37:45.187295Z | 40.0 Hz, 8001 samples | mag:6.3 dist:82.3 baz:31.5 slow:5.22
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-20T04:37:45.187295Z | 40.0 Hz, 8001 samples | mag:6.3 dist:82.3 baz:31.5 slow:5.22
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-21T10:26:15.912490Z | 40.0 Hz, 8001 samples | mag:6.0 dist:82.3 baz:31.6 slow:5.22
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-21T10:26:15.912490Z | 40.0 Hz, 8001 samples | mag:6.0 dist:82.3 baz:31.6 slow:5.22
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-21T10:26:15.912490Z | 40.0 Hz, 8001 samples | mag:6.0 dist:82.3 baz:31.6 slow:5.22
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-22T14:36:10.920999Z | 40.0 Hz, 8001 samples | mag:6.2 dist:89.2 baz:299.2 slow:4.68
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-22T14:36:10.920999Z | 40.0 Hz, 8001 samples | mag:6.2 dist:89.2 baz:299.2 slow:4.68
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-22T14:36:10.920999Z | 40.0 Hz, 8001 samples | mag:6.2 dist:89.2 baz:299.2 slow:4.68
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-02-24T02:41:14.935979Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-02-24T02:41:14.935979Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-02-24T02:41:14.935979Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-03-07T13:30:29.059927Z | 40.0 Hz, 8001 samples | mag:5.7 dist:79.1 baz:359.5 slow:5.47
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-03-07T13:30:29.059927Z | 40.0 Hz, 8001 samples | mag:5.7 dist:79.1 baz:359.5 slow:5.47
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-03-07T13:30:29.059927Z | 40.0 Hz, 8001 samples | mag:5.7 dist:79.1 baz:359.5 slow:5.47
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-03-09T03:01:16.536682Z | 40.0 Hz, 8001 samples | mag:5.7 dist:84.1 baz:273.2 slow:5.08
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-03-09T03:01:16.536682Z | 40.0 Hz, 8001 samples | mag:5.7 dist:84.1 baz:273.2 slow:5.08
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-03-09T03:01:16.536682Z | 40.0 Hz, 8001 samples | mag:5.7 dist:84.1 baz:273.2 slow:5.08
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-03-10T21:07:24.499304Z | 40.0 Hz, 8001 samples | mag:6.2 dist:77.8 baz:265.8 slow:5.52
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-03-10T21:07:24.499304Z | 40.0 Hz, 8001 samples | mag:6.2 dist:77.8 baz:265.8 slow:5.52
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-03-10T21:07:24.499304Z | 40.0 Hz, 8001 samples | mag:6.2 dist:77.8 baz:265.8 slow:5.52
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-03-23T10:26:30.953760Z | 40.0 Hz, 8001 samples | mag:5.6 dist:86.7 baz:55.6 slow:4.87
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-03-23T10:26:30.953760Z | 40.0 Hz, 8001 samples | mag:5.6 dist:86.7 baz:55.6 slow:4.87
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-03-23T10:26:30.953760Z | 40.0 Hz, 8001 samples | mag:5.6 dist:86.7 baz:55.6 slow:4.87
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-10T16:35:29.351502Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.7 baz:122.0 slow:5.19
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-10T16:35:29.351502Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.7 baz:122.0 slow:5.19
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-10T16:35:29.351502Z | 40.0 Hz, 8001 samples | mag:5.7 dist:82.7 baz:122.0 slow:5.19
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-20T01:55:38.959954Z | 40.0 Hz, 8001 samples | mag:6.3 dist:86.7 baz:54.8 slow:4.87
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-20T01:55:38.959954Z | 40.0 Hz, 8001 samples | mag:6.3 dist:86.7 baz:54.8 slow:4.87
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-20T01:55:38.959954Z | 40.0 Hz, 8001 samples | mag:6.3 dist:86.7 baz:54.8 slow:4.87
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-20T11:57:54.900888Z | 40.0 Hz, 8001 samples | mag:5.9 dist:86.8 baz:54.7 slow:4.86
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-20T11:57:54.900888Z | 40.0 Hz, 8001 samples | mag:5.9 dist:86.8 baz:54.7 slow:4.86
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-20T11:57:54.900888Z | 40.0 Hz, 8001 samples | mag:5.9 dist:86.8 baz:54.7 slow:4.86
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-20T12:12:41.683954Z | 40.0 Hz, 8001 samples | mag:6.0 dist:86.8 baz:54.7 slow:4.87
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-20T12:12:41.683954Z | 40.0 Hz, 8001 samples | mag:6.0 dist:86.8 baz:54.7 slow:4.87
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-20T12:12:41.683954Z | 40.0 Hz, 8001 samples | mag:6.0 dist:86.8 baz:54.7 slow:4.87
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-24T14:07:36.560538Z | 40.0 Hz, 8001 samples | mag:6.2 dist:71.5 baz:333.4 slow:6.04
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-24T14:07:36.560538Z | 40.0 Hz, 8001 samples | mag:6.2 dist:71.5 baz:333.4 slow:6.04
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-24T14:07:36.560538Z | 40.0 Hz, 8001 samples | mag:6.2 dist:71.5 baz:333.4 slow:6.04
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T06:21:44.598652Z | 40.0 Hz, 8001 samples | mag:7.8 dist:61.8 baz:79.0 slow:6.74
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T06:21:44.598652Z | 40.0 Hz, 8001 samples | mag:7.8 dist:61.8 baz:79.0 slow:6.74
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T06:21:44.598652Z | 40.0 Hz, 8001 samples | mag:7.8 dist:61.8 baz:79.0 slow:6.74
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T06:48:23.255345Z | 40.0 Hz, 8001 samples | mag:5.7 dist:87.6 baz:36.6 slow:4.79
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T06:48:23.255345Z | 40.0 Hz, 8001 samples | mag:5.7 dist:87.6 baz:36.6 slow:4.79
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T06:48:23.255345Z | 40.0 Hz, 8001 samples | mag:5.7 dist:87.6 baz:36.6 slow:4.79
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T06:55:40.509609Z | 40.0 Hz, 8001 samples | mag:6.7 dist:61.9 baz:78.9 slow:6.74
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T06:55:40.509609Z | 40.0 Hz, 8001 samples | mag:6.7 dist:61.9 baz:78.9 slow:6.74
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T06:55:40.509609Z | 40.0 Hz, 8001 samples | mag:6.7 dist:61.9 baz:78.9 slow:6.74
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T07:06:58.987514Z | 40.0 Hz, 8001 samples | mag:5.6 dist:62.7 baz:78.6 slow:6.68
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T07:06:58.987514Z | 40.0 Hz, 8001 samples | mag:5.6 dist:62.7 baz:78.6 slow:6.68
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T07:06:58.987514Z | 40.0 Hz, 8001 samples | mag:5.6 dist:62.7 baz:78.6 slow:6.68
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T09:27:31.712181Z | 40.0 Hz, 8001 samples | mag:5.6 dist:63.3 baz:77.0 slow:6.64
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T09:27:31.712181Z | 40.0 Hz, 8001 samples | mag:5.6 dist:63.3 baz:77.0 slow:6.64
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T09:27:31.712181Z | 40.0 Hz, 8001 samples | mag:5.6 dist:63.3 baz:77.0 slow:6.64
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-25T23:26:37.062349Z | 40.0 Hz, 8001 samples | mag:5.5 dist:62.2 baz:79.2 slow:6.72
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-25T23:26:37.062349Z | 40.0 Hz, 8001 samples | mag:5.5 dist:62.2 baz:79.2 slow:6.72
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-25T23:26:37.062349Z | 40.0 Hz, 8001 samples | mag:5.5 dist:62.2 baz:79.2 slow:6.72
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-04-26T07:19:35.339485Z | 40.0 Hz, 8001 samples | mag:6.7 dist:62.9 baz:78.5 slow:6.66
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-04-26T07:19:35.339485Z | 40.0 Hz, 8001 samples | mag:6.7 dist:62.9 baz:78.5 slow:6.66
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-04-26T07:19:35.339485Z | 40.0 Hz, 8001 samples | mag:6.7 dist:62.9 baz:78.5 slow:6.66
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-02T17:03:38.087656Z | 40.0 Hz, 8001 samples | mag:5.7 dist:88.5 baz:37.6 slow:4.73
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-02T17:03:38.087656Z | 40.0 Hz, 8001 samples | mag:5.7 dist:88.5 baz:37.6 slow:4.73
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-02T17:03:38.087656Z | 40.0 Hz, 8001 samples | mag:5.7 dist:88.5 baz:37.6 slow:4.73
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-10T21:38:45.818935Z | 40.0 Hz, 8001 samples | mag:5.9 dist:89.6 baz:36.4 slow:4.64
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-10T21:38:45.818935Z | 40.0 Hz, 8001 samples | mag:5.9 dist:89.6 baz:36.4 slow:4.64
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-10T21:38:45.818935Z | 40.0 Hz, 8001 samples | mag:5.9 dist:89.6 baz:36.4 slow:4.64
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-12T07:15:45.404488Z | 40.0 Hz, 8001 samples | mag:7.2 dist:63.0 baz:78.4 slow:6.66
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-12T07:15:45.404488Z | 40.0 Hz, 8001 samples | mag:7.2 dist:63.0 baz:78.4 slow:6.66
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-12T07:15:45.404488Z | 40.0 Hz, 8001 samples | mag:7.2 dist:63.0 baz:78.4 slow:6.66
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-12T07:27:48.572026Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.0 baz:78.3 slow:6.66
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-12T07:27:48.572026Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.0 baz:78.3 slow:6.66
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-12T07:27:48.572026Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.0 baz:78.3 slow:6.66
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-12T07:47:21.110535Z | 40.0 Hz, 8001 samples | mag:6.1 dist:63.1 baz:78.5 slow:6.65
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-12T07:47:21.110535Z | 40.0 Hz, 8001 samples | mag:6.1 dist:63.1 baz:78.5 slow:6.65
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-12T07:47:21.110535Z | 40.0 Hz, 8001 samples | mag:6.1 dist:63.1 baz:78.5 slow:6.65
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-12T21:25:18.080217Z | 40.0 Hz, 8001 samples | mag:6.8 dist:82.6 baz:33.0 slow:5.19
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-12T21:25:18.080217Z | 40.0 Hz, 8001 samples | mag:6.8 dist:82.6 baz:33.0 slow:5.19
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-12T21:25:18.080217Z | 40.0 Hz, 8001 samples | mag:6.8 dist:82.6 baz:33.0 slow:5.19
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-24T05:04:32.080343Z | 40.0 Hz, 8001 samples | mag:6.3 dist:69.6 baz:200.6 slow:6.17
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-24T05:04:32.080343Z | 40.0 Hz, 8001 samples | mag:6.3 dist:69.6 baz:200.6 slow:6.17
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-24T05:04:32.080343Z | 40.0 Hz, 8001 samples | mag:6.3 dist:69.6 baz:200.6 slow:6.17
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-05-29T07:11:24.342368Z | 40.0 Hz, 8001 samples | mag:6.8 dist:71.8 baz:350.1 slow:5.99
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-05-29T07:11:24.342368Z | 40.0 Hz, 8001 samples | mag:6.8 dist:71.8 baz:350.1 slow:5.99
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-05-29T07:11:24.342368Z | 40.0 Hz, 8001 samples | mag:6.8 dist:71.8 baz:350.1 slow:5.99
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-01T07:04:38.856035Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.5 baz:329.3 slow:5.59
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-01T07:04:38.856035Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.5 baz:329.3 slow:5.59
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-01T07:04:38.856035Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.5 baz:329.3 slow:5.59
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-01T20:23:27.887510Z | 40.0 Hz, 8001 samples | mag:5.9 dist:77.6 baz:329.5 slow:5.59
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-01T20:23:27.887510Z | 40.0 Hz, 8001 samples | mag:5.9 dist:77.6 baz:329.5 slow:5.59
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-01T20:23:27.887510Z | 40.0 Hz, 8001 samples | mag:5.9 dist:77.6 baz:329.5 slow:5.59
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-08T06:13:14.487380Z | 40.0 Hz, 8001 samples | mag:6.0 dist:80.3 baz:31.8 slow:5.37
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-08T06:13:14.487380Z | 40.0 Hz, 8001 samples | mag:6.0 dist:80.3 baz:31.8 slow:5.37
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-08T06:13:14.487380Z | 40.0 Hz, 8001 samples | mag:6.0 dist:80.3 baz:31.8 slow:5.37
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-10T08:45:22.438532Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-10T08:45:22.438532Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-10T08:45:22.438532Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.8 slow:5.21
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-11T04:57:51.978428Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.7 slow:5.21
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-11T04:57:51.978428Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.7 slow:5.21
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-11T04:57:51.978428Z | 40.0 Hz, 8001 samples | mag:5.6 dist:82.4 baz:31.7 slow:5.21
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-17T13:04:23.783457Z | 40.0 Hz, 8001 samples | mag:6.9 dist:88.6 baz:199.0 slow:4.72
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-17T13:04:23.783457Z | 40.0 Hz, 8001 samples | mag:6.9 dist:88.6 baz:199.0 slow:4.72
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-17T13:04:23.783457Z | 40.0 Hz, 8001 samples | mag:6.9 dist:88.6 baz:199.0 slow:4.72
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-06-24T22:42:57.075511Z | 40.0 Hz, 8001 samples | mag:5.8 dist:66.4 baz:348.9 slow:6.37
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-06-24T22:42:57.075511Z | 40.0 Hz, 8001 samples | mag:5.8 dist:66.4 baz:348.9 slow:6.37
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-06-24T22:42:57.075511Z | 40.0 Hz, 8001 samples | mag:5.8 dist:66.4 baz:348.9 slow:6.37
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-03T01:16:50.699449Z | 40.0 Hz, 8001 samples | mag:6.4 dist:51.5 baz:75.5 slow:7.49
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-03T01:16:50.699449Z | 40.0 Hz, 8001 samples | mag:6.4 dist:51.5 baz:75.5 slow:7.49
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-03T01:16:50.699449Z | 40.0 Hz, 8001 samples | mag:6.4 dist:51.5 baz:75.5 slow:7.49
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-07T05:22:31.815692Z | 40.0 Hz, 8001 samples | mag:6.2 dist:80.0 baz:26.7 slow:5.39
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-07T05:22:31.815692Z | 40.0 Hz, 8001 samples | mag:6.2 dist:80.0 baz:26.7 slow:5.39
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-07T05:22:31.815692Z | 40.0 Hz, 8001 samples | mag:6.2 dist:80.0 baz:26.7 slow:5.39
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-09T18:44:57.652913Z | 40.0 Hz, 8001 samples | mag:5.5 dist:81.1 baz:32.7 slow:5.29
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-09T18:44:57.652913Z | 40.0 Hz, 8001 samples | mag:5.5 dist:81.1 baz:32.7 slow:5.29
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-09T18:44:57.652913Z | 40.0 Hz, 8001 samples | mag:5.5 dist:81.1 baz:32.7 slow:5.29
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-16T11:12:14.147906Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.2 baz:259.0 slow:6.64
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-16T11:12:14.147906Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.2 baz:259.0 slow:6.64
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-16T11:12:14.147906Z | 40.0 Hz, 8001 samples | mag:5.7 dist:63.2 baz:259.0 slow:6.64
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-16T15:27:00.297525Z | 40.0 Hz, 8001 samples | mag:6.5 dist:63.3 baz:259.0 slow:6.63
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-16T15:27:00.297525Z | 40.0 Hz, 8001 samples | mag:6.5 dist:63.3 baz:259.0 slow:6.63
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-16T15:27:00.297525Z | 40.0 Hz, 8001 samples | mag:6.5 dist:63.3 baz:259.0 slow:6.63
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-23T04:06:33.571677Z | 40.0 Hz, 8001 samples | mag:5.5 dist:56.3 baz:213.3 slow:7.14
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-23T04:06:33.571677Z | 40.0 Hz, 8001 samples | mag:5.5 dist:56.3 baz:213.3 slow:7.14
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-23T04:06:33.571677Z | 40.0 Hz, 8001 samples | mag:5.5 dist:56.3 baz:213.3 slow:7.14
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-27T05:01:36.772945Z | 40.0 Hz, 8001 samples | mag:6.9 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-27T05:01:36.772945Z | 40.0 Hz, 8001 samples | mag:6.9 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-27T05:01:36.772945Z | 40.0 Hz, 8001 samples | mag:6.9 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-27T05:07:38.350719Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-27T05:07:38.350719Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-27T05:07:38.350719Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.2 slow:5.61
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-27T06:17:25.066574Z | 40.0 Hz, 8001 samples | mag:5.5 dist:77.1 baz:357.1 slow:5.62
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-27T06:17:25.066574Z | 40.0 Hz, 8001 samples | mag:5.5 dist:77.1 baz:357.1 slow:5.62
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-27T06:17:25.066574Z | 40.0 Hz, 8001 samples | mag:5.5 dist:77.1 baz:357.1 slow:5.62
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-27T07:52:22.296345Z | 40.0 Hz, 8001 samples | mag:5.6 dist:77.1 baz:357.0 slow:5.62
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-27T07:52:22.296345Z | 40.0 Hz, 8001 samples | mag:5.6 dist:77.1 baz:357.0 slow:5.62
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-27T07:52:22.296345Z | 40.0 Hz, 8001 samples | mag:5.6 dist:77.1 baz:357.0 slow:5.62
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-27T07:55:21.173595Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.0 slow:5.61
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-27T07:55:21.173595Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.0 slow:5.61
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-27T07:55:21.173595Z | 40.0 Hz, 8001 samples | mag:5.7 dist:77.2 baz:357.0 slow:5.61
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-29T00:22:30.074352Z | 40.0 Hz, 8001 samples | mag:5.9 dist:79.4 baz:270.1 slow:5.45
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-29T00:22:30.074352Z | 40.0 Hz, 8001 samples | mag:5.9 dist:79.4 baz:270.1 slow:5.45
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-29T00:22:30.074352Z | 40.0 Hz, 8001 samples | mag:5.9 dist:79.4 baz:270.1 slow:5.45
# NL.HGN.02.BHE | -50.0s - 150.0s onset:2015-07-29T02:46:45.662549Z | 40.0 Hz, 8001 samples | mag:6.3 dist:68.2 baz:349.1 slow:6.24
# NL.HGN.02.BHN | -50.0s - 150.0s onset:2015-07-29T02:46:45.662549Z | 40.0 Hz, 8001 samples | mag:6.3 dist:68.2 baz:349.1 slow:6.24
# NL.HGN.02.BHZ | -50.0s - 150.0s onset:2015-07-29T02:46:45.662549Z | 40.0 Hz, 8001 samples | mag:6.3 dist:68.2 baz:349.1 slow:6.24
# Number of Events: 153 events
